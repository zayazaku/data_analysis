# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('cars.csv')

# %% [markdown]
# Inspecting dataframes

# %%
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  price  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
data.shape
# Out:
# (201, 29)

# %%
data.describe(include = 'object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
data.values
# Out:
# array([[3, 122, 'alfa-romero', ..., 'Medium', 0, 1],
#        [3, 122, 'alfa-romero', ..., 'Medium', 0, 1],
#        [1, 122, 'alfa-romero', ..., 'Medium', 0, 1],
#        ...,
#        [-1, 95, 'volvo', ..., 'Medium', 0, 1],
#        [-1, 95, 'volvo', ..., 'Medium', 1, 0],
#        [-1, 95, 'volvo', ..., 'Medium', 0, 1]], dtype=object)

# %% [markdown]
# sorting

# %%
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  price  \
# ...

# %%
data.sort_values("price").head()
# Out:
#      symboling  normalized-losses        make aspiration num-of-doors  \
# 134          2                 83      subaru        std          two
# 17           2                121   chevrolet        std          two
# 47           1                104       mazda        std          two
# 146          1                 87      toyota        std          two
# 73           2                161  mitsubishi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 134  hatchback          fwd           front        93.7  0.753964  ...
# 17   hatchback          fwd           front        88.4  0.678039  ...
# 47   hatchback          fwd           front        93.1  0.764536  ...
# 146  hatchback          fwd           front        95.7  0.762614  ...
# 73   hatchback          fwd           front        93.7  0.755887  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  price  \
# ...

# %%
data.sort_values("price", ascending = False).head()
# Out:
#      symboling  normalized-losses           make aspiration num-of-doors  \
# 71           1                122  mercedes-benz        std          two
# 15           0                122            bmw        std          two
# 70           0                122  mercedes-benz        std         four
# 125          3                122        porsche        std          two
# 16           0                122            bmw        std         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 71       hardtop          rwd           front       112.0  0.957232  ...
# 15         sedan          rwd           front       103.5  0.931283  ...
# 70         sedan          rwd           front       120.9  1.000000  ...
# 125  convertible          rwd            rear        89.5  0.811629  ...
# 16         sedan          rwd           front       110.0  0.946660  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  price  \
# ...

# %% [markdown]
# subsetting

# %%
print(data[["make", "num-of-doors", "body-style", "engine-location", "horsepower", "price", "diesel", "gas"]].head())
# Out:
#           make num-of-doors   body-style engine-location  horsepower  price  \
# 0  alfa-romero          two  convertible           front       111.0  13495
# 1  alfa-romero          two  convertible           front       111.0  16500
# 2  alfa-romero          two    hatchback           front       154.0  16500
# 3         audi         four        sedan           front       102.0  13950
# 4         audi         four        sedan           front       115.0  17450
#
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
data[data['body-style'] == "sedan"].head()
# Out:
#    symboling  normalized-losses  make aspiration num-of-doors body-style  \
# 3          2                164  audi        std         four      sedan
# 4          2                164  audi        std         four      sedan
# 5          2                122  audi        std          two      sedan
# 6          1                158  audi        std         four      sedan
# 8          1                158  audi      turbo         four      sedan
#
#   drive-wheels engine-location  wheel-base    length  ...  compression-ratio  \
# 3          fwd           front        99.8  0.848630  ...               10.0
# 4          4wd           front        99.4  0.848630  ...                8.0
# 5          fwd           front        99.8  0.851994  ...                8.5
# 6          fwd           front       105.8  0.925997  ...                8.5
# 8          fwd           front       105.8  0.925997  ...                8.3
#
# ...

# %%
data[data['price'] <= 10000].head(20)
# Out:
#     symboling  normalized-losses       make aspiration num-of-doors  \
# 17          2                121  chevrolet        std          two
# 18          1                 98  chevrolet        std          two
# 19          0                 81  chevrolet        std         four
# 20          1                118      dodge        std          two
# 21          1                118      dodge        std          two
# 22          1                118      dodge      turbo          two
# 23          1                148      dodge        std         four
# 24          1                148      dodge        std         four
# 25          1                148      dodge        std         four
# 26          1                148      dodge      turbo         four
# 27         -1                110      dodge        std         four
# 29          2                137      honda        std          two
# 30          2                137      honda        std          two
# ...

# %%
data["length_100"] = data["length"] * 100

# %%
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg  price  city-L/100km  \
# ...

# %% [markdown]
# summary statistics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
data["price"].mean()
# Out:
# 13207.129353233831

# %%
data["length_100"].mean()
# Out:
# 83.71023307412933

# %%
data["price"].median()
# Out:
# 10295.0

# %%
#a custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

# %%
iqr(data["price"])
# Out:
# 8725.0
